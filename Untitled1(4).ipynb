# %%
#survey 2021
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

first_sur=pd.read_csv('Servay_2021.csv')
first_sur.head(20)
full=first_sur[first_sur['Employment']=='Student, full-time' ]
part=first_sur[first_sur['Employment']=='Student, part-time']
result=pd.concat([full, part])
result
New_Data=result.drop(['ResponseId', 'MainBranch','Country','US_State','UK_Country','EdLevel','YearsCode','YearsCodePro','DevType','OrgSize','Currency','CompTotal','CompFreq','LanguageWantToWorkWith','DatabaseHaveWorkedWith','DatabaseWantToWorkWith','PlatformHaveWorkedWith','PlatformWantToWorkWith','WebframeHaveWorkedWith','NEWCollabToolsHaveWorkedWith','NEWCollabToolsWantToWorkWith','ToolsTechWantToWorkWith','ToolsTechHaveWorkedWith','MiscTechWantToWorkWith','MiscTechHaveWorkedWith','WebframeWantToWorkWith','OpSys','NEWStuck','NEWSOSites','SOVisitFreq','SOAccount','SOPartFreq','SOComm','NEWOtherComms','Gender','Trans','Age1stCode','Sexuality','Ethnicity','Accessibility','MentalHealth','SurveyLength','SurveyEase','ConvertedCompYearly'],axis=1)
New_Data.head(20)
# Out:
#              Employment                                          LearnCode  \
# 1    Student, full-time  Other online resources (ex: videos, blogs, etc...
# 2    Student, full-time  Other online resources (ex: videos, blogs, etc...
# 7    Student, full-time             School;Online Courses or Certification
# 15   Student, full-time                                                NaN
# 20   Student, full-time                                   School;Colleague
# 21   Student, full-time  Other online resources (ex: videos, blogs, etc...
# 22   Student, full-time                     School;Friend or family member
# 42   Student, full-time  Other online resources (ex: videos, blogs, etc...
# 49   Student, full-time  Coding Bootcamp;Other online resources (ex: vi...
# 53   Student, full-time  Friend or family member;Online Courses or Cert...
# 54   Student, full-time  Other online resources (ex: videos, blogs, etc...
# ...

# %%
# survey 2021
New_Data.count()
# Out:
# Employment                876
# LearnCode                 831
# LanguageHaveWorkedWith    866
# Age                       851
# dtype: int64

# %%
# survey 2021
first_sur['Age1stCode'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
New_Data.groupby('Age')['Employment','LearnCode'].sum()
# Out:
# <ipython-input-4-62962daaf7ce>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   New_Data.groupby('Age')['Employment','LearnCode'].sum()
#                                                            Employment  \
# Age
# 18-24 years old     Student, full-timeStudent, full-timeStudent, f...
# 25-34 years old     Student, full-timeStudent, full-timeStudent, f...
# 35-44 years old     Student, full-timeStudent, full-timeStudent, f...
# 45-54 years old                                    Student, part-time
# 65 years or older                                  Student, full-time
# Prefer not to say   Student, full-timeStudent, full-timeStudent, f...
# Under 18 years old  Student, full-timeStudent, full-timeStudent, f...
#
#                                                             LearnCode
# Age
# 18-24 years old     Other online resources (ex: videos, blogs, etc...
# ...

# %%
New_Data.describe()
# Out:
#                 Employment                                        LearnCode  \
# count                  876                                              831
# unique                   2                                              128
# top     Student, full-time  Other online resources (ex: videos, blogs, etc)
# freq                   763                                              111
#
#        LanguageHaveWorkedWith              Age
# count                     866              851
# unique                    734                7
# top                    Python  18-24 years old
# freq                       18              501

# %%
# survey2022
first_sur2=pd.read_csv('survey_2022.csv')
full=first_sur2[first_sur2['Employment']=='Student, full-time' ]
part=first_sur2[first_sur2['Employment']=='Student, part-time']
result=pd.concat([full, part])
result1=result[['Employment','LearnCode','LanguageHaveWorkedWith','Age']]
result1
# Out:
#               Employment                                          LearnCode  \
# 5     Student, full-time  Books / Physical media;School (i.e., Universit...
# 19    Student, full-time   Books / Physical media;Coding Bootcamp;Colleague
# 35    Student, full-time  Other online resources (e.g., videos, blogs, f...
# 38    Student, full-time  Friend or family member;Other online resources...
# 44    Student, full-time            School (i.e., University, College, etc)
# ...                  ...                                                ...
# 7686  Student, part-time  Friend or family member;Other online resources...
# 7724  Student, part-time  Books / Physical media;Other online resources ...
# 7743  Student, part-time  Books / Physical media;Other online resources ...
# 7773  Student, part-time  Books / Physical media;Other online resources ...
# 7792  Student, part-time  Other online resources (e.g., videos, blogs, f...
#
# ...

# %%
first_sur2['Age'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
result1.count()
# Out:
# Employment                773
# LearnCode                 771
# LanguageHaveWorkedWith    765
# Age                       753
# dtype: int64

# %%
result1.describe()
# Out:
#                 Employment                                          LearnCode  \
# count                  773                                                771
# unique                   2                                                160
# top     Student, full-time  Other online resources (e.g., videos, blogs, f...
# freq                   700                                                 92
#
#        LanguageHaveWorkedWith              Age
# count                     765              753
# unique                    654                6
# top                    Python  18-24 years old
# freq                       11              450

# %%
result1.groupby('Age')['Employment','LearnCode'].sum()
# Out:
# <ipython-input-10-9c10a1b4633f>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   result1.groupby('Age')['Employment','LearnCode'].sum()
#                                                            Employment  \
# Age
# 18-24 years old     Student, full-timeStudent, full-timeStudent, f...
# 25-34 years old     Student, full-timeStudent, full-timeStudent, f...
# 35-44 years old     Student, full-timeStudent, full-timeStudent, f...
# 45-54 years old                  Student, full-timeStudent, full-time
# Prefer not to say   Student, full-timeStudent, full-timeStudent, f...
# Under 18 years old  Student, full-timeStudent, full-timeStudent, f...
#
#                                                             LearnCode
# Age
# 18-24 years old     Books / Physical media;Coding Bootcamp;Colleag...
# 25-34 years old     Books / Physical media;School (i.e., Universit...
# ...
